# %%
import pandas as pd
import numpy as np
from datetime import datetime

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.feature_extraction.text import CountVectorizer

import os

import requests
from bs4 import BeautifulSoup
import time

from collections import Counter

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Read in Player_By_Game Data from Scraper

# %%
# Read in all the partial data pieces

df1 = pd.read_csv('../data/player_boxscores/offset_0-200000.csv')
df2 = pd.read_csv('../data/player_boxscores/offset_200000-300000.csv')
df3 = pd.read_csv('../data/player_boxscores/offset_300000-475000.csv')
df4 = pd.read_csv('../data/player_boxscores/offset_475000-550000.csv')
df5 = pd.read_csv('../data/player_boxscores/offset_550000-600000.csv')
df6 = pd.read_csv('../data/player_boxscores/offset_600000-725000.csv')
df7 = pd.read_csv('../data/player_boxscores/offset_725000-909000.csv')

# %%
# Aggregate all the segmented data into one dataframe

df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
# Check starting shape

df.shape
# Out:
# (909700, 31)

# %%
df.head()
# Out:
#    Unnamed: 0           player pos   date_game           school_id  \
# 0           0     Nate Wolters   G  2013-02-07  South Dakota State
# 1           1       Mike James   G  2011-01-04               Lamar
# 2           2   Marshon Brooks   G  2011-02-23          Providence
# 3           3  Jimmer Fredette   G  2011-03-11       Brigham Young
# 4           4    Markus Howard   G  2018-01-03           Marquette
#
#        opp_id game_result   gs  mp  fg     ...      orb  drb  trb  ast  stl  \
# 0        IPFW           W  1.0  40  17     ...        2    2    4    3    1
# 1         NaN           W  0.0  28  18     ...        1    4    5    3    1
# 2  Notre Dame           L  1.0  40  20     ...        2    3    5    4    1
# 3  New Mexico           W  1.0  40  22     ...        0    2    2    4    1
# 4  Providence           W  1.0  44  17     ...        0    1    1    2    2
#
#    blk  tov  pf  pts  game_score
# 0    1    3   0   53        42.6
# 1    0    1   4   52        36.3
# 2    0    1   4   52        42.3
# 3    0    2   2   52        36.5
# 4    0    2   1   52        39.8
#
# [5 rows x 31 columns]

# %% [markdown]
# ## EDA And Cleaning of Player_By_Game Data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player', 'pos', 'date_game', 'school_id', 'opp_id',
#        'game_result', 'gs', 'mp', 'fg', 'fga', 'fg_pct', 'fg2', 'fg2a',
#        'fg2_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft', 'fta', 'ft_pct', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'game_score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# player              0
# pos                91
# date_game           0
# school_id           0
# opp_id          38014
# game_result         0
# gs               1558
# mp                  0
# fg                  0
# fga                 0
# fg_pct         107301
# fg2                 0
# fg2a                0
# fg2_pct        173922
# fg3                 0
# fg3a                0
# fg3_pct        384069
# ft                  0
# fta                 0
# ft_pct         415522
# orb                 0
# drb                 0
# trb                 0
# ast                 0
# stl                 0
# blk                 0
# tov                 0
# pf                  0
# pts                 0
# game_score          0
# dtype: int64

# %%
# Drop these columns because they are derived explicity from existing features
df.drop(['fg_pct', 'fg2_pct', 'fg3_pct', 'ft_pct', 'trb'], axis=1, inplace=True)

# %%
# Drop erroneous column
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# If we don't know whether they started or not, chances are they did not. We'll set np.nan 
# of 'gs' to 0.
df['gs'] = df['gs'].fillna(value=0)

# %%
# Check and drop duplicated rows, probably resulting from scraping overlap
df.duplicated().sum()
# Out:
# 1526

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# player             0
# pos               90
# date_game          0
# school_id          0
# opp_id         37961
# game_result        0
# gs                 0
# mp                 0
# fg                 0
# fga                0
# fg2                0
# fg2a               0
# fg3                0
# fg3a               0
# ft                 0
# fta                0
# orb                0
# drb                0
# ast                0
# stl                0
# blk                0
# tov                0
# pf                 0
# pts                0
# game_score         0
# dtype: int64

# %%
# We will be bringing in a lot of opponent data as features, so not knowing the opp_id is 
# useless to us. So let's drop the np.nan values in opp_id

df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# player         0
# pos            0
# date_game      0
# school_id      0
# opp_id         0
# game_result    0
# gs             0
# mp             0
# fg             0
# fga            0
# fg2            0
# fg2a           0
# fg3            0
# fg3a           0
# ft             0
# fta            0
# orb            0
# drb            0
# ast            0
# stl            0
# blk            0
# tov            0
# pf             0
# pts            0
# game_score     0
# dtype: int64

# %%
# Check resulting shape. We still have 96% of our original rows. Pretty good
df.shape
# Out:
# (870131, 25)

# %%
# Convert date_game to datetime type

df['date_game'] = pd.to_datetime(df['date_game'])

# %%
# Create a year and month feature

df['year'] = df['date_game'].map(lambda x: x.year)
df['month'] = df['date_game'].map(lambda x: x.month)

# %%
# Get an idea of timeframe 

print(df['date_game'].min())
print(df['date_game'].max())
# Out:
# 2010-11-08 00:00:00
# 2018-03-07 00:00:00

# %%
# Make a 'season' feature, where the year it ended is defined as the season

season_list = []
for i in df['date_game']:
    if i.month == 11 or i.month == 12:
        season_list.append(i.year + 1)
    else:
        season_list.append(i.year)

# %%
df['season'] = season_list

# %%
# Codify Win/Loss with 1/0
df['W'] = df['game_result'].map(lambda x: 1 if x == 'W' else 0)

# %%
# Dummify position
#df = pd.concat([df, pd.get_dummies(df['pos'])], axis=1)

# %%
# Drop game_result: We have one-hot encoded
df.drop('game_result', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# player        0
# pos           0
# date_game     0
# school_id     0
# opp_id        0
# gs            0
# mp            0
# fg            0
# fga           0
# fg2           0
# fg2a          0
# fg3           0
# fg3a          0
# ft            0
# fta           0
# orb           0
# drb           0
# ast           0
# stl           0
# blk           0
# tov           0
# pf            0
# pts           0
# game_score    0
# year          0
# month         0
# season        0
# W             0
# dtype: int64

# %%
df.dtypes
# Out:
# player                object
# pos                   object
# date_game     datetime64[ns]
# school_id             object
# opp_id                object
# gs                   float64
# mp                     int64
# fg                     int64
# fga                    int64
# fg2                    int64
# fg2a                   int64
# fg3                    int64
# fg3a                   int64
# ft                     int64
# fta                    int64
# orb                    int64
# drb                    int64
# ast                    int64
# stl                    int64
# blk                    int64
# tov                    int64
# pf                     int64
# pts                    int64
# game_score           float64
# year                   int64
# month                  int64
# season                 int64
# W                      int64
# dtype: object

# %%
df.to_csv('../data/player_boxscores_df.csv')

# %% [markdown]
# ## Bring in School Data

# %%
school_df = pd.read_csv('../data/schools.csv')

# %%
school_df.head()
# Out:
#    Unnamed: 0              School  WinLossPct    SRS    SOS  Year
# 0           0           Air Force       0.323  -4.90   3.13  2010
# 1           1               Akron       0.686   2.82  -1.50  2010
# 2           2         Alabama A&M       0.407 -20.19 -13.71  2010
# 3           3  Alabama-Birmingham       0.735   9.46   2.90  2010
# 4           4       Alabama State       0.516 -14.41 -12.02  2010

# %% [markdown]
# # Player-by-Player Evaluation

# %%
df.set_index(['player', 'date_game'], drop=False, inplace=True)

# %%
stats = ['gs', 'mp', 'fg2', 'fg2a', 'fg3', 'fg3a', 'ft', 'fta','orb', 'drb', 'ast', 
         'stl', 'blk', 'tov', 'pf', 'pts', 'game_score', 'W']

# %%
# Specifically needed for rolling mean and rolling median

lookbacks = ['_3day_', '_10day_', '_30day_', '_60day_', '_90day_', '_120day_']

metrics = ['mean', 'median']

# %%
# Specifically needed for rolling mean and rolling median

all_rolling = []

for i in metrics:
    for j in lookbacks:
        for k in stats:
            all_rolling.append(i+j+k)

# %%
# Note: There will be some noise introduced by players with same name (no unique id associated)
players = df['player'].unique()
len(players)
# Out:
# 16566

# %%
stats.append('date_game')

# %%
count = 0
stamp = datetime.now()
for player in players:
    if count % 500 == 0:
        diff_time = datetime.now() - stamp
        stamp = datetime.now()
        print('parsing...', count)
        print('last parsing block took: ', (diff_time.seconds / 60), ' minutes')
    player_df = df.loc[player][stats].sort_values('date_game')
    
    ewm_01 = player_df.drop('date_game', axis=1).ewm(alpha = 0.1, min_periods=1).mean().shift()
    ewm_03 = player_df.drop('date_game', axis=1).ewm(alpha = 0.3, min_periods=1).mean().shift()
    ewm_05 = player_df.drop('date_game', axis=1).ewm(alpha = 0.5, min_periods=1).mean().shift()
    ewm_07 = player_df.drop('date_game', axis=1).ewm(alpha = 0.7, min_periods=1).mean().shift()
    ewm_09 = player_df.drop('date_game', axis=1).ewm(alpha = 0.9, min_periods=1).mean().shift()
    ewm_10 = player_df.drop('date_game', axis=1).ewm(alpha = 1.0, min_periods=1).mean().shift()
    
    this_df = pd.concat([ewm_01, ewm_03, ewm_05, ewm_07, ewm_09, ewm_10], axis=1)

    this_df['player'] = player

    this_df.to_csv('../data/player_ewm/'+player.replace(' ', '_')+'.csv')
    count += 1

# %% [markdown]
# ## Player-by-Player Aggregation

# %%
for (dirpath, dirnames, filenames) in os.walk('../data/player_ewm/'):
    break

# %%
len(filenames)

# %%
f = filenames # [:3] for testing

with open('../data/player_ewm_df.csv', 'wb') as output:
    for filename in f:
        with open('../data/player_ewm/'+filename, 'rb') as _input:
            for i, line in enumerate(_input):
                if i == 0:
                    continue       
                #print(line) # for testing
                output.write(line)

# %%
player_ewm_df = pd.read_csv('../data/player_ewm_df.csv', skiprows=1, header=None)

# %%
stats = pd.Series(stats)

ewm_cols = []
for i in ['01', '03', '05', '07', '09', '10']:
    for j in stats.drop(18):
        ewm_cols.append('ewm'+j+'_'+i)

# %%
ewm_cols.insert(0, 'date_game')
ewm_cols.append('player')
len(ewm_cols)

# %%
player_ewm_df.columns = ewm_cols

# %%
player_ewm_df.head()

# %%
player_ewm_df['date_game'] = pd.to_datetime(player_ewm_df['date_game'])

# %%
player_ewm_df.set_index(['player', 'date_game'], drop=False, inplace=True)

# %%
joined_df = df.join(player_ewm_df, how='left', on=['player', 'date_game'], rsuffix='_right')

# %% [markdown]
# ## Player-by-Player Modeling

# %%
ewm_cols.append('pts')

# %%
joined_df.isnull().sum()

# %%
joined_df.shape

# %%
joined_df.fillna(0, inplace=True)

# %%
trial_df = joined_df[ewm_cols].drop(['date_game', 'player'], axis=1)

# %%
trial_df.shape

# %%
X = trial_df.drop('pts', axis=1)
y = trial_df['pts']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %% [markdown]
# ### LinReg

# %%
player_linreg = LinearRegression()
player_linreg.fit(X_train, y_train)

# %%
score_lr = cross_val_score(player_linreg, X_train, y_train, cv=5)
score_lr

# %%
score_lr.mean()

# %% [markdown]
# #### Need to GroupBy to get Team Score Predictions

# %%
temp_lr = X

# %%
lr_preds = player_linreg.predict(temp_lr)

# %%
lr_preds.shape

# %%
joined_df['player_preds'] = lr_preds

# %%
team_actual = joined_df.groupby(['school_id', 'date_game']).sum()['pts']
team_preds = joined_df.groupby(['school_id', 'date_game']).sum()['player_preds']

# %%
print(team_actual.shape)
team_actual.isnull().sum()

# %%
print(team_preds.shape)
team_preds.isnull().sum()

# %%
r2_score(team_actual, team_preds)

# %%
plt.scatter(team_actual, team_preds, alpha=0.2)
plt.xlim(0,150)
plt.ylim(0,150)

# %% [markdown]
# ### RFRegressor

# %%
player_rf = RandomForestRegressor(max_depth=2)
player_rf.fit(X_train, y_train)

# %%
score_rf = cross_val_score(player_rf, X_train, y_train, cv=5)
score_rf

# %%
score_rf.mean()

# %% [markdown]
# #### Need to GroupBy to get Team Score Predictions

# %% [markdown]
# # Team Evaluation

# %%
team_df = df.groupby(['school_id', 'opp_id', 'date_game']).sum()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'date_game' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#   if __name__ == '__main__':

# %%
# Sum of 'game_started' flag and 'minutes_played' meaningless, so we can drop
team_df.drop(['gs', 'mp', 'year', 'month', 'season'], axis=1, inplace=True)

# %%
team_df.reset_index(inplace=True)

# %%
team_df.head()
# Out:
#            school_id               opp_id  date_game  fg  fga  fg2  fg2a  fg3  \
# 0  Abilene Christian            Air Force 2017-12-06  23   54   14    29    9
# 1  Abilene Christian       Arkansas State 2017-11-13  25   45   22    32    3
# 2  Abilene Christian  Arkansas-Pine Bluff 2014-12-23  24   45   14    25   10
# 3  Abilene Christian          Boise State 2014-12-20  11   55    5    36    6
# 4  Abilene Christian  Bowling Green State 2017-11-26  34   64   28    48    6
#
#    fg3a  ft ...  orb  drb  ast  stl  blk  tov  pf  pts  game_score   W
# 0    25   7 ...    7   17   11    8    4   12  16   62        40.3  12
# 1    13  16 ...    5   14   11    4    2   13  19   69        46.1   0
# 2    20  11 ...    5   22   15    7    2   18  21   69        47.7  11
# 3    19   5 ...   11   10    4    4    0    9  12   33         2.2   0
# 4    16  14 ...   10   26   18    2    6    8  18   88        73.6  12
#
# [5 rows x 21 columns]

# %%
team_df[(team_df['school_id']=='Nevada-Las Vegas') & (team_df['date_game'] == '2018-03-07')]
# Out:
# Empty DataFrame
# Columns: [school_id, opp_id, date_game, fg, fga, fg2, fg2a, fg3, fg3a, ft, fta, orb, drb, ast, stl, blk, tov, pf, pts, game_score, W]
# Index: []
#
# [0 rows x 21 columns]

# %%
team_df[(team_df['school_id']=='Air Force') & (team_df['date_game'] == '2017-12-06')].index[0]
# Out:
# 128

# %%
# STOP RUNNING THIS FUCKING CELL YOU FUCKING MORON, THIS SHIT TAKES FOREVER
index_dict = {}
for i in team_df.index:
    row = team_df.loc[i]
    try:
        opp_index = team_df[(team_df['school_id']==row['opp_id']) & (team_df['date_game'] == row['date_game'])].index[0]
    except:
        opp_index = np.nan
    index_dict[i] = opp_index

# %%
index_dict[0]
# Out:
# 128

# %%
len(index_dict)
# Out:
# 87171

# %%
def_stats = ['fg', 'fga', 'fg2', 'fg2a', 'fg3', 'fg3a', 'ft', 'fta', 'orb', 'drb', 'ast', 
             'stl', 'blk', 'tov', 'pf', 'pts', 'game_score', 'W']

team_opp_df = pd.DataFrame(columns=def_stats)

count = 0
for key in range(0,87171):
    if count % 500 == 0:
        print('parsed...', count)
    try:
        team_opp_df = team_opp_df.append(team_df.loc[index_dict[key]][def_stats])
    except:
        team_opp_df = team_opp_df.append({'fg':np.nan, 'fga':np.nan, 'fg2':np.nan, 'fg2a':np.nan, 
                            'fg3':np.nan, 'fg3a':np.nan, 'ft':np.nan, 'fta':np.nan, 
                            'orb':np.nan, 'drb':np.nan, 'ast':np.nan, 'stl':np.nan, 
                            'blk':np.nan, 'tov':np.nan, 'pf':np.nan, 'pts':np.nan, 
                            'game_score':np.nan, 'W':np.nan}, ignore_index=True)
    count += 1
# Out:
# parsed... 0
# parsed... 500
# parsed... 1000
# parsed... 1500
# parsed... 2000
# parsed... 2500
# parsed... 3000
# parsed... 3500
# parsed... 4000
# parsed... 4500
# parsed... 5000
# parsed... 5500
# parsed... 6000
# parsed... 6500
# parsed... 7000
# parsed... 7500
# parsed... 8000
# parsed... 8500
# parsed... 9000
# parsed... 9500
# parsed... 10000
# parsed... 10500
# parsed... 11000
# parsed... 11500
# parsed... 12000
# parsed... 12500
# parsed... 13000
# parsed... 13500
# parsed... 14000
# parsed... 14500
# parsed... 15000
# parsed... 15500
# parsed... 16000
# parsed... 16500
# parsed... 17000
# parsed... 17500
# parsed... 18000
# parsed... 18500
# parsed... 19000
# parsed... 19500
# parsed... 20000
# parsed... 20500
# parsed... 21000
# parsed... 21500
# parsed... 22000
# parsed... 22500
# parsed... 23000
# parsed... 23500
# parsed... 24000
# parsed... 24500
# parsed... 25000
# parsed... 25500
# parsed... 26000
# parsed... 26500
# parsed... 27000
# parsed... 27500
# parsed... 28000
# parsed... 28500
# parsed... 29000
# parsed... 29500
# parsed... 30000
# parsed... 30500
# parsed... 31000
# parsed... 31500
# parsed... 32000
# parsed... 32500
# parsed... 33000
# parsed... 33500
# parsed... 34000
# parsed... 34500
# parsed... 35000
# parsed... 35500
# parsed... 36000
# parsed... 36500
# parsed... 37000
# parsed... 37500
# parsed... 38000
# parsed... 38500
# parsed... 39000
# parsed... 39500
# parsed... 40000
# parsed... 40500
# parsed... 41000
# parsed... 41500
# parsed... 42000
# parsed... 42500
# parsed... 43000
# parsed... 43500
# parsed... 44000
# parsed... 44500
# parsed... 45000
# parsed... 45500
# parsed... 46000
# parsed... 46500
# parsed... 47000
# parsed... 47500
# parsed... 48000
# parsed... 48500
# parsed... 49000
# parsed... 49500
# parsed... 50000
# parsed... 50500
# parsed... 51000
# parsed... 51500
# parsed... 52000
# parsed... 52500
# parsed... 53000
# parsed... 53500
# parsed... 54000
# parsed... 54500
# parsed... 55000
# parsed... 55500
# parsed... 56000
# parsed... 56500
# parsed... 57000
# parsed... 57500
# parsed... 58000
# parsed... 58500
# parsed... 59000
# parsed... 59500
# parsed... 60000
# parsed... 60500
# parsed... 61000
# parsed... 61500
# parsed... 62000
# parsed... 62500
# parsed... 63000
# parsed... 63500
# parsed... 64000
# parsed... 64500
# parsed... 65000
# parsed... 65500
# parsed... 66000
# parsed... 66500
# parsed... 67000
# parsed... 67500
# parsed... 68000
# parsed... 68500
# parsed... 69000
# parsed... 69500
# parsed... 70000
# parsed... 70500
# parsed... 71000
# parsed... 71500
# parsed... 72000
# parsed... 72500
# parsed... 73000
# parsed... 73500
# parsed... 74000
# parsed... 74500
# parsed... 75000
# parsed... 75500
# parsed... 76000
# parsed... 76500
# parsed... 77000
# parsed... 77500
# parsed... 78000
# parsed... 78500
# parsed... 79000
# parsed... 79500
# parsed... 80000
# parsed... 80500
# parsed... 81000
# parsed... 81500
# parsed... 82000
# parsed... 82500
# parsed... 83000
# parsed... 83500
# parsed... 84000
# parsed... 84500
# parsed... 85000
# parsed... 85500
# parsed... 86000
# parsed... 86500
# parsed... 87000

# %%
team_opp_df.isnull().sum()
# Out:
# fg            50
# fga           50
# fg2           50
# fg2a          50
# fg3           50
# fg3a          50
# ft            50
# fta           50
# orb           50
# drb           50
# ast           50
# stl           50
# blk           50
# tov           50
# pf            50
# pts           50
# game_score    50
# W             50
# dtype: int64

# %%
# Merge them before dropping NA's
print(team_opp_df.shape)
print(team_df.shape)
# Out:
# (87171, 18)
# (87171, 21)

# %%
team_opp_df.head()
# Out:
#    fg fga fg2 fg2a fg3 fg3a  ft fta orb drb ast stl blk tov  pf pts  \
# 0  25  51  22   33   3   18   5   8   5  28  15   5   2  20  14  58
# 1  28  48  21   35   7   13  20  26   9  15   7   6   1   9  12  83
# 2  20  53  15   34   5   19  16  20  11  18   5   3   2  14  19  61
# 3  31  52  21   32  10   20   5   6   8  32  17   2   6  12   7  77
# 4  30  72  22   48   8   24  15  22  17  20   9   4   3   8  18  83
#
#    game_score   W
# 0        34.3   0
# 1        66.8   7
# 2        29.7   0
# 3        71.1  13
# 4        56.9   0

# %%
opp_df_cols = ['def_fg', 'def_fga', 'def_fg2', 'def_fg2a', 'def_fg3', 'def_fg3a', 'def_ft', 
               'def_fta', 'def_orb', 'def_drb', 'def_ast', 'def_stl', 'def_blk', 'def_tov', 
               'def_pf', 'def_pts', 'def_game_score', 'def_W']

# %%
team_opp_df.columns = opp_df_cols

# %%
team_df = pd.concat([team_df, team_opp_df], axis=1)

# %%
team_df.isnull().sum()
# Out:
# school_id          0
# opp_id             0
# date_game          0
# fg                 0
# fga                0
# fg2                0
# fg2a               0
# fg3                0
# fg3a               0
# ft                 0
# fta                0
# orb                0
# drb                0
# ast                0
# stl                0
# blk                0
# tov                0
# pf                 0
# pts                0
# game_score         0
# W                  0
# def_fg            49
# def_fga           49
# def_fg2           49
# def_fg2a          49
# def_fg3           49
# def_fg3a          49
# def_ft            49
# def_fta           49
# def_orb           49
# def_drb           49
# def_ast           49
# def_stl           49
# def_blk           49
# def_tov           49
# def_pf            49
# def_pts           49
# def_game_score    49
# def_W             49
# dtype: int64

# %%
team_df.dropna(inplace=True)

# %%
teams = team_df['school_id'].unique()

# %%
team_df.set_index(['school_id', 'date_game'], drop=False, inplace=True)

# %%
# Change to 0/1 Flags
team_df['W'] = team_df['W'].apply(lambda x: 1 if x > 0 else 0)
team_df['def_W'] = team_df['def_W'].apply(lambda x: 1 if x > 0 else 0)

# %%
team_df.loc['Abilene Christian'].sort_values('date_game')
# Out:
#                            school_id                    opp_id  date_game  fg  \
# school_id
# Abilene Christian  Abilene Christian                  Duquesne 2013-11-09  22
# Abilene Christian  Abilene Christian           St. Bonaventure 2013-11-11  14
# Abilene Christian  Abilene Christian                  Maryland 2013-11-13  17
# Abilene Christian  Abilene Christian                      Iowa 2013-11-17  14
# Abilene Christian  Abilene Christian           Texas Christian 2013-11-19  19
# Abilene Christian  Abilene Christian                    Xavier 2013-11-25  23
# Abilene Christian  Abilene Christian                    Towson 2013-11-30  18
# Abilene Christian  Abilene Christian               New Orleans 2014-01-09  28
# Abilene Christian  Abilene Christian    Southeastern Louisiana 2014-01-11  23
# Abilene Christian  Abilene Christian              Oral Roberts 2014-01-16  19
# Abilene Christian  Abilene Christian          Central Arkansas 2014-01-18  25
# Abilene Christian  Abilene Christian                     Lamar 2014-01-23  18
# Abilene Christian  Abilene Christian         Sam Houston State 2014-01-25  16
# Abilene Christian  Abilene Christian         Stephen F. Austin 2014-01-30  14
# Abilene Christian  Abilene Christian        Northwestern State 2014-02-01  20
# Abilene Christian  Abilene Christian           Houston Baptist 2014-02-06  27
# Abilene Christian  Abilene Christian  Texas A&M-Corpus Christi 2014-02-08  21
# Abilene Christian  Abilene Christian            Incarnate Word 2014-02-13  22
# Abilene Christian  Abilene Christian            Nicholls State 2014-02-27  17
# Abilene Christian  Abilene Christian             McNeese State 2014-03-01  30
# Abilene Christian  Abilene Christian            Incarnate Word 2014-03-08  20
# Abilene Christian  Abilene Christian                     Tulsa 2014-11-19  15
# Abilene Christian  Abilene Christian                  Duquesne 2014-11-22  25
# Abilene Christian  Abilene Christian              UC-Riverside 2014-11-29  19
# Abilene Christian  Abilene Christian          Sacramento State 2014-12-04  23
# Abilene Christian  Abilene Christian                   Houston 2014-12-06  22
# Abilene Christian  Abilene Christian               Loyola (IL) 2014-12-17  14
# Abilene Christian  Abilene Christian               Boise State 2014-12-20  11
# Abilene Christian  Abilene Christian      South Carolina State 2014-12-22  23
# Abilene Christian  Abilene Christian       Arkansas-Pine Bluff 2014-12-23  24
# ...                              ...                       ...        ...  ..
# Abilene Christian  Abilene Christian         Sam Houston State 2017-02-25  25
# Abilene Christian  Abilene Christian            Incarnate Word 2017-03-01  32
# Abilene Christian  Abilene Christian           Houston Baptist 2017-03-04  30
# Abilene Christian  Abilene Christian            Arkansas State 2017-11-13  25
# Abilene Christian  Abilene Christian                  Lipscomb 2017-11-20  25
# Abilene Christian   62   19    48    6    14  25  ...          9       30
# Abilene Christian   53   12    37    7    16  11  ...         17       27
# Abilene Christian   45   16    28    7    17  19  ...         17       15
# Abilene Christian   67   14    36    8    31   7  ...          9       28
# Abilene Christian   55    8    33    6    22  10  ...          6       35
# Abilene Christian   55    5    36    6    19   5  ...          8       32
# Abilene Christian   54   15    30    8    24  11  ...          7       28
# Abilene Christian   45   14    25   10    20  11  ...         11       18
# ...                ...  ...   ...  ...   ...  ..  ...        ...      ...
# Abilene Christian   51   14    30   11    21  23  ...         11       26
# Abilene Christian   63   26    45    6    18   5  ...          2       23
# Abilene Christian   59   22    35    8    24   4  ...         10       19
# Abilene Christian   45   22    32    3    13  16  ...          9       15
# Abilene Christian   56   19    36    6    20  11  ...          6       28
# Abilene Christian   65   25    51    8    14  11  ...          5       23
# Abilene Christian   58   19    35    8    23  16  ...          6       21
# Abilene Christian   64   28    48    6    16  14  ...         17       20
# Abilene Christian   54   14    29    9    25   7  ...          5       28
# Abilene Christian   58   16    29   10    29  10  ...          7       26
# Abilene Christian   62   19    41    6    21   9  ...          9       25
# Abilene Christian   61   14    41    4    20   7  ...          8       32
# Abilene Christian   48   16    30    8    18  18  ...          5       22
# Abilene Christian   55   16    33    9    22  16  ...          5       25
# Abilene Christian   60   22    36    6    24  17  ...          5       31
# Abilene Christian   66   24    48    5    18   7  ...          7       29
# Abilene Christian   55   24    36    6    19  16  ...         11       23
# Abilene Christian   53   15    35    8    18  15  ...         12       25
# Abilene Christian   43   13    26    6    17  22  ...         15       18
# Abilene Christian   56   18    34   10    22  14  ...          7       20
# Abilene Christian   51   12    28    6    23  24  ...          4       26
# Abilene Christian   49   18    30    8    19  14  ...         10       22
# Abilene Christian   52   21    34    7    18  14  ...          7       18
# Abilene Christian   60   22    39    3    21  12  ...         16       21
# Abilene Christian   62   22    38    9    24   9  ...          5       17
# Abilene Christian   59   16    44    4    15  10  ...          7       25
# Abilene Christian   54   19    30    4    24  17  ...          8       26
# Abilene Christian   68   29    54    3    14   5  ...          9       25
# Abilene Christian   50   15    32    7    18   5  ...          6       22
# Abilene Christian   56   16    36    6    20  19  ...          8       23
#
#                    def_ast  def_stl  def_blk  def_tov  def_pf  def_pts  \
# school_id
# Abilene Christian       19        4        2       10      22       94
# Abilene Christian       15        7        7        9      23       75
# Abilene Christian       12        9       10       17       8       67
# Abilene Christian       25       11        5        5      10      103
# Abilene Christian       11        7        3        6      20       71
# Abilene Christian       18        8        7        8      16       93
# Abilene Christian       12        1        9       14      17       74
# Abilene Christian       13        2        3       13      22       87
# Abilene Christian       17        2        5       12      23       85
# Abilene Christian       10        8        6       11      15       82
# Abilene Christian       11       11        1       16      21       72
# Abilene Christian        7        5        4       17      18       65
# Abilene Christian       14        9        2       11      22       70
# Abilene Christian       20       11       11       16      20       64
# Abilene Christian       24       13        6       13      15       84
# Abilene Christian       18        6        2       14      28       81
# Abilene Christian       15        8        2       16      19       71
# Abilene Christian       15        5        5       11      18       80
# Abilene Christian       17        9        4        5      21       79
# Abilene Christian       21        6        2       13      20       95
# Abilene Christian            49.2      1
# Abilene Christian            42.5      0
# Abilene Christian            25.2      0
# Abilene Christian            53.0      1
# Abilene Christian            48.2      0
# Abilene Christian            55.7      1
# Abilene Christian            42.7      0
# Abilene Christian            64.9      1
# Abilene Christian            47.7      1
# Abilene Christian            46.3      0
# Abilene Christian            47.6      1
# Abilene Christian            51.9      1
# Abilene Christian            49.8      1
# Abilene Christian            60.1      1
# Abilene Christian            34.1      0
#
# [128 rows x 39 columns]

# %%
team_rolling_stats = ['date_game', 'fg2', 'fg2a', 'fg3', 'fg3a', 'ft', 'fta', 'orb', 'drb', 
                      'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'game_score', 'W', 'def_fg2', 
                      'def_fg2a', 'def_fg3', 'def_fg3a', 'def_ft', 'def_fta', 'def_orb', 
                      'def_drb', 'def_ast', 'def_stl', 'def_blk', 'def_tov', 'def_pf', 
                      'def_pts', 'def_game_score', 'def_W']

# %%
count = 0
stamp = datetime.now()
for team in teams:
    if count % 500 == 0:
        diff_time = datetime.now() - stamp
        stamp = datetime.now()
        print('parsing...', count)
        print('last parsing block took: ', (diff_time.seconds / 60), ' minutes')
    one_team_df = team_df.loc[team][team_rolling_stats].sort_values('date_game')
    
    ewm_01 = one_team_df.drop('date_game', axis=1).ewm(alpha = 0.1, min_periods=1).mean().shift()
    ewm_03 = one_team_df.drop('date_game', axis=1).ewm(alpha = 0.3, min_periods=1).mean().shift()
    ewm_05 = one_team_df.drop('date_game', axis=1).ewm(alpha = 0.5, min_periods=1).mean().shift()
    ewm_07 = one_team_df.drop('date_game', axis=1).ewm(alpha = 0.7, min_periods=1).mean().shift()
    ewm_09 = one_team_df.drop('date_game', axis=1).ewm(alpha = 0.9, min_periods=1).mean().shift()
    ewm_10 = one_team_df.drop('date_game', axis=1).ewm(alpha = 1.0, min_periods=1).mean().shift()
    
    this_df = pd.concat([ewm_01, ewm_03, ewm_05, ewm_07, ewm_09, ewm_10], axis=1)

    this_df['date_game'] = one_team_df['date_game']

    this_df.to_csv('../data/team_ewm/'+team.replace(' ', '_')+'.csv')
    count += 1
# Out:
# parsing... 0
# last parsing block took:  0.0  minutes

# %% [markdown]
# count = 0
# stamp = datetime.now()
# for player in players:
#     if count % 500 == 0:
#         diff_time = datetime.now() - stamp
#         stamp = datetime.now()
#         print('parsing...', count)
#         print('last parsing block took: ', (diff_time.seconds / 60), ' minutes')
#     player_df = df.loc[player][stats].sort_values('date_game')
#
#     mean_3day = player_df.drop('date_game', axis=1).rolling(window=3, center=False, min_periods=1).mean().shift()
#     mean_10day = player_df.drop('date_game', axis=1).rolling(window=10, center=False, min_periods=1).mean().shift()
#     mean_30day = player_df.drop('date_game', axis=1).rolling(window=30, center=False, min_periods=1).mean().shift()
#     mean_60day = player_df.drop('date_game', axis=1).rolling(window=60, center=False, min_periods=1).mean().shift()
#     mean_90day = player_df.drop('date_game', axis=1).rolling(window=90, center=False, min_periods=1).mean().shift()
#     mean_120day = player_df.drop('date_game', axis=1).rolling(window=120, center=False, min_periods=1).mean().shift()
#
#     #median_3day = player_df.drop('date_game', axis=1).rolling(window=3, center=False, min_periods=1).median()
#     #median_10day = player_df.drop('date_game', axis=1).rolling(window=10, center=False, min_periods=1).median()
#     #median_30day = player_df.drop('date_game', axis=1).rolling(window=30, center=False, min_periods=1).median()
#     #median_60day = player_df.drop('date_game', axis=1).rolling(window=60, center=False, min_periods=1).median()
#     #median_90day = player_df.drop('date_game', axis=1).rolling(window=90, center=False, min_periods=1).median()
#     #median_120day = player_df.drop('date_game', axis=1).rolling(window=120, center=False, min_periods=1).median()
#
#     this_df = pd.concat([mean_3day, mean_10day, mean_30day, mean_60day, mean_90day, mean_120day,
#                         median_3day, median_10day, median_30day, median_60day, median_90day,
#                         median_120day], axis=1)
#
#     this_df['player'] = player
#
#     this_df.to_csv('../data/player_rolling/'+player.replace(' ', '_')+'.csv')
#     count += 1

# %%
for (dirpath, dirnames, filenames) in os.walk('../data/team_ewm/'):
    break

# %%
len(filenames)
# Out:
# 352

# %%
f = filenames # [:3] for testing

with open('../data/team_ewm_df.csv', 'wb') as output:
    for filename in f:
        with open('../data/team_ewm/'+filename, 'rb') as _input:
            for i, line in enumerate(_input):
                if i == 0:
                    continue       
                #print(line) # for testing
                output.write(line)

# %%
team_ewm_df = pd.read_csv('../data/team_ewm_df.csv', skiprows=1, header=None)

# %%
team_ewm_df.head()
# Out:
#           0          1          2         3          4          5    \
# 0  High Point   8.000000  32.000000  8.000000  22.000000  17.000000
# 1  High Point  13.263158  39.894737  4.842105  14.105263  19.105263
# 2  High Point  13.166052  38.826568  5.269373  13.328413  19.435424
# 3  High Point  14.862460  38.876999  4.609479  12.360570  19.308811
# 4  High Point  18.070572  38.662841  3.728065  13.493492  18.745012
#
#          6          7          8          9       ...       184   185   186  \
# 0  29.000000  10.000000  19.000000  10.000000     ...      27.0  19.0  14.0
# 1  31.105263  10.000000  20.052632   7.894737     ...      26.0  16.0   3.0
# 2  28.852399   8.154982  22.247232   9.409594     ...      27.0   7.0   4.0
# 3  28.895318   7.528351  22.175342   9.290491     ...      26.0   3.0   7.0
# 4  28.188298   8.131914  22.132524  10.928915     ...      16.0  11.0  10.0
#
#    187   188   189   190   191  192         193
# 0  8.0  11.0  19.0  79.0  79.6  1.0  2010-11-23
# 1  1.0  14.0  24.0  71.0  45.2  1.0  2010-11-28
# 2  7.0  10.0  24.0  70.0  45.8  1.0  2010-12-02
# 3  1.0  19.0  23.0  64.0  29.0  0.0  2010-12-04
# 4  4.0  22.0  22.0  73.0  43.8  0.0  2010-12-08
#
# [5 rows x 194 columns]

# %%
team_rolling_stats = pd.Series(team_rolling_stats)

# %%
team_rolling_stats
# Out:
# 0          date_game
# 1                fg2
# 2               fg2a
# 3                fg3
# 4               fg3a
# 5                 ft
# 6                fta
# 7                orb
# 8                drb
# 9                ast
# 10               stl
# 11               blk
# 12               tov
# 13                pf
# 14               pts
# 15        game_score
# 16                 W
# 17           def_fg2
# 18          def_fg2a
# 19           def_fg3
# 20          def_fg3a
# 21            def_ft
# 22           def_fta
# 23           def_orb
# 24           def_drb
# 25           def_ast
# 26           def_stl
# 27           def_blk
# 28           def_tov
# 29            def_pf
# 30           def_pts
# 31    def_game_score
# 32             def_W
# dtype: object

# %%
team_ewm_cols = []
for i in ['01', '03', '05', '07', '09', '10']:
    for j in team_rolling_stats.drop(0):
        team_ewm_cols.append('ewm'+j+'_'+i)

# %%
len(team_ewm_cols)
# Out:
# 192

# %%
team_ewm_cols.insert(0, 'school_id')
team_ewm_cols.append('date_game')
len(team_ewm_cols)
# Out:
# 194

# %%
team_ewm_df.columns = team_ewm_cols

# %%
team_ewm_df['date_game'] = pd.to_datetime(team_ewm_df['date_game'])
team_ewm_df.set_index(['school_id', 'date_game'], drop=False, inplace=True)

# %%
team_joined_df = team_df.join(team_ewm_df, how='left', on=['school_id', 'date_game'], rsuffix='_right')

# %%
team_joined_df.head()
# Out:
#                                       school_id               opp_id  \
# school_id         date_game
# Abilene Christian 2017-12-06  Abilene Christian            Air Force
#                   2017-11-13  Abilene Christian       Arkansas State
#                   2014-12-23  Abilene Christian  Arkansas-Pine Bluff
#                   2014-12-20  Abilene Christian          Boise State
#                   2017-11-26  Abilene Christian  Bowling Green State
#
#                               date_game  fg  fga  fg2  fg2a  fg3  fg3a  ft  \
# school_id         date_game
# Abilene Christian 2017-12-06 2017-12-06  23   54   14    29    9    25   7
#                   2017-11-13 2017-11-13  25   45   22    32    3    13  16
#                   2014-12-23 2014-12-23  24   45   14    25   10    20  11
#                   2014-12-20 2014-12-20  11   55    5    36    6    19   5
#                   2017-11-26 2017-11-26  34   64   28    48    6    16  14
#
#                                    ...         ewmdef_drb_10  ewmdef_ast_10  \
# school_id         date_game        ...
# Abilene Christian 2017-12-06       ...                  20.0            9.0
#                   2017-11-13       ...                  19.0           18.0
#                   2014-12-23       ...                  28.0           11.0
#                   2014-12-20       ...                  35.0           17.0
#                   2017-11-26       ...                  21.0           17.0
#
#                               ewmdef_stl_10  ewmdef_blk_10  ewmdef_tov_10  \
# school_id         date_game
# Abilene Christian 2017-12-06            4.0            3.0            8.0
#                   2017-11-13            4.0            2.0            9.0
#                   2014-12-23            8.0            6.0           22.0
#                   2014-12-20            5.0            2.0           14.0
#                   2017-11-26            7.0            2.0           12.0
#
#                               ewmdef_pf_10  ewmdef_pts_10  \
# school_id         date_game
# Abilene Christian 2017-12-06          18.0           83.0
#                   2017-11-13           8.0           81.0
#                   2014-12-23          21.0           59.0
#                   2014-12-20          13.0           83.0
#                   2017-11-26          12.0           88.0
#
#                               ewmdef_game_score_10  ewmdef_W_10  \
# school_id         date_game
# Abilene Christian 2017-12-06                  56.9          0.0
#                   2017-11-13                  69.2          1.0
#                   2014-12-23                  35.5          0.0
#                   2014-12-20                  75.8          1.0
#                   2017-11-26                  75.4          1.0
#
#                               date_game_right
# school_id         date_game
# Abilene Christian 2017-12-06       2017-12-06
#                   2017-11-13       2017-11-13
#                   2014-12-23       2014-12-23
#                   2014-12-20       2014-12-20
#                   2017-11-26       2017-11-26
#
# [5 rows x 233 columns]

# %%
team_joined_df.shape
# Out:
# (87136, 233)

# %% [markdown]
# ## Team Modeling

# %%
# Will drop the "first" observation of each team
team_joined_df.dropna(inplace=True)

# %%
list(team_joined_df.columns)
# Out:
# ['school_id',
#  'opp_id',
#  'date_game',
#  'fg',
#  'fga',
#  'fg2',
#  'fg2a',
#  'fg3',
#  'fg3a',
#  'ft',
#  'fta',
#  'orb',
#  'drb',
#  'ast',
#  'stl',
#  'blk',
#  'tov',
#  'pf',
#  'pts',
#  'game_score',
#  'W',
#  'def_fg',
#  'def_fga',
#  'def_fg2',
#  'def_fg2a',
#  'def_fg3',
#  'def_fg3a',
#  'def_ft',
#  'def_fta',
#  'def_orb',
#  'def_drb',
#  'def_ast',
#  'def_stl',
#  'def_blk',
#  'def_tov',
#  'def_pf',
#  'def_pts',
#  'def_game_score',
#  'def_W',
#  'school_id_right',
#  'ewmfg2_01',
#  'ewmfg2a_01',
#  'ewmfg3_01',
#  'ewmfg3a_01',
#  'ewmft_01',
#  'ewmfta_01',
#  'ewmorb_01',
#  'ewmdrb_01',
#  'ewmast_01',
#  'ewmstl_01',
#  'ewmblk_01',
#  'ewmtov_01',
#  'ewmpf_01',
#  'ewmpts_01',
#  'ewmgame_score_01',
#  'ewmW_01',
#  'ewmdef_fg2_01',
#  'ewmdef_fg2a_01',
#  'ewmdef_fg3_01',
#  'ewmdef_fg3a_01',
#  'ewmdef_ft_01',
#  'ewmdef_fta_01',
#  'ewmdef_orb_01',
#  'ewmdef_drb_01',
#  'ewmdef_ast_01',
#  'ewmdef_stl_01',
#  'ewmdef_blk_01',
#  'ewmdef_tov_01',
#  'ewmdef_pf_01',
#  'ewmdef_pts_01',
#  'ewmdef_game_score_01',
#  'ewmdef_W_01',
#  'ewmfg2_03',
#  'ewmfg2a_03',
#  'ewmfg3_03',
#  'ewmfg3a_03',
#  'ewmft_03',
#  'ewmfta_03',
#  'ewmorb_03',
#  'ewmdrb_03',
#  'ewmast_03',
#  'ewmstl_03',
#  'ewmblk_03',
#  'ewmtov_03',
#  'ewmpf_03',
#  'ewmpts_03',
#  'ewmgame_score_03',
#  'ewmW_03',
#  'ewmdef_fg2_03',
#  'ewmdef_fg2a_03',
#  'ewmdef_fg3_03',
#  'ewmdef_fg3a_03',
#  'ewmdef_ft_03',
#  'ewmdef_fta_03',
#  'ewmdef_orb_03',
#  'ewmdef_drb_03',
#  'ewmdef_ast_03',
#  'ewmdef_stl_03',
#  'ewmdef_blk_03',
#  'ewmdef_tov_03',
#  'ewmdef_pf_03',
#  'ewmdef_pts_03',
#  'ewmdef_game_score_03',
#  'ewmdef_W_03',
#  'ewmfg2_05',
#  'ewmfg2a_05',
#  'ewmfg3_05',
#  'ewmfg3a_05',
#  'ewmft_05',
#  'ewmfta_05',
#  'ewmorb_05',
#  'ewmdrb_05',
#  'ewmast_05',
#  'ewmstl_05',
#  'ewmblk_05',
#  'ewmtov_05',
#  'ewmpf_05',
#  'ewmpts_05',
#  'ewmgame_score_05',
#  'ewmW_05',
#  'ewmdef_fg2_05',
#  'ewmdef_fg2a_05',
#  'ewmdef_fg3_05',
#  'ewmdef_fg3a_05',
#  'ewmdef_ft_05',
#  'ewmdef_fta_05',
#  'ewmdef_orb_05',
#  'ewmdef_drb_05',
#  'ewmdef_ast_05',
#  'ewmdef_stl_05',
#  'ewmdef_blk_05',
#  'ewmdef_tov_05',
#  'ewmdef_pf_05',
#  'ewmdef_pts_05',
#  'ewmdef_game_score_05',
#  'ewmdef_W_05',
#  'ewmfg2_07',
#  'ewmfg2a_07',
#  'ewmfg3_07',
#  'ewmfg3a_07',
#  'ewmft_07',
#  'ewmfta_07',
#  'ewmorb_07',
#  'ewmdrb_07',
#  'ewmast_07',
#  'ewmstl_07',
#  'ewmblk_07',
#  'ewmtov_07',
#  'ewmpf_07',
#  'ewmpts_07',
#  'ewmgame_score_07',
#  'ewmW_07',
#  'ewmdef_fg2_07',
#  'ewmdef_fg2a_07',
#  'ewmdef_fg3_07',
#  'ewmdef_fg3a_07',
#  'ewmdef_ft_07',
#  'ewmdef_fta_07',
#  'ewmdef_orb_07',
#  'ewmdef_drb_07',
#  'ewmdef_ast_07',
#  'ewmdef_stl_07',
#  'ewmdef_blk_07',
#  'ewmdef_tov_07',
#  'ewmdef_pf_07',
#  'ewmdef_pts_07',
#  'ewmdef_game_score_07',
#  'ewmdef_W_07',
#  'ewmfg2_09',
#  'ewmfg2a_09',
#  'ewmfg3_09',
#  'ewmfg3a_09',
#  'ewmft_09',
#  'ewmfta_09',
#  'ewmorb_09',
#  'ewmdrb_09',
#  'ewmast_09',
#  'ewmstl_09',
#  'ewmblk_09',
#  'ewmtov_09',
#  'ewmpf_09',
#  'ewmpts_09',
#  'ewmgame_score_09',
#  'ewmW_09',
#  'ewmdef_fg2_09',
#  'ewmdef_fg2a_09',
#  'ewmdef_fg3_09',
#  'ewmdef_fg3a_09',
#  'ewmdef_ft_09',
#  'ewmdef_fta_09',
#  'ewmdef_orb_09',
#  'ewmdef_drb_09',
#  'ewmdef_ast_09',
#  'ewmdef_stl_09',
#  'ewmdef_blk_09',
#  'ewmdef_tov_09',
#  'ewmdef_pf_09',
#  'ewmdef_pts_09',
#  'ewmdef_game_score_09',
#  'ewmdef_W_09',
#  'ewmfg2_10',
#  'ewmfg2a_10',
#  'ewmfg3_10',
#  'ewmfg3a_10',
#  'ewmft_10',
#  'ewmfta_10',
#  'ewmorb_10',
#  'ewmdrb_10',
#  'ewmast_10',
#  'ewmstl_10',
#  'ewmblk_10',
#  'ewmtov_10',
#  'ewmpf_10',
#  'ewmpts_10',
#  'ewmgame_score_10',
#  'ewmW_10',
#  'ewmdef_fg2_10',
#  'ewmdef_fg2a_10',
#  'ewmdef_fg3_10',
#  'ewmdef_fg3a_10',
#  'ewmdef_ft_10',
#  'ewmdef_fta_10',
#  'ewmdef_orb_10',
#  'ewmdef_drb_10',
#  'ewmdef_ast_10',
#  'ewmdef_stl_10',
#  'ewmdef_blk_10',
#  'ewmdef_tov_10',
#  'ewmdef_pf_10',
#  'ewmdef_pts_10',
#  'ewmdef_game_score_10',
#  'ewmdef_W_10',
#  'date_game_right']

# %%
team_ewm_cols.append('pts')

# %%
team_modeling_feats = pd.Series(team_ewm_cols)

# %%
team_modeling_feats.drop([0, 193], inplace=True)

# %%
trial_df = team_joined_df[test_list]

# %%
X = trial_df.drop('pts', axis=1)
y = trial_df['pts']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (
# 2014-02-08      81.105580       87.0           81.0
# 2014-02-13      72.010558       69.0           71.0
# 2014-02-27      79.201056       68.0           80.0
# 2014-03-01      79.020106       60.0           79.0
# 2014-03-08      93.402011       91.0           95.0
# 2014-11-19      62.440201       56.0           59.0
# 2014-11-22      64.744020       39.0           65.0
# 2014-11-29      98.274402       81.0          102.0
# 2014-12-04      78.227440       56.0           76.0
# 2014-12-06      62.722744       72.0           61.0
# 2014-12-17      70.172274       59.0           71.0
# 2014-12-20      81.717227       44.0           83.0
# 2014-12-22      77.471723       33.0           77.0
# 2014-12-23      60.847172       65.0           59.0
# 2014-12-28      60.984717       69.0           61.0
# ...                   ...        ...            ...
# 2017-02-25      58.150054       44.0           56.0
# 2017-03-01      78.715005       84.0           81.0
# 2017-03-04      87.971501       75.0           89.0
# 2017-11-13      81.697150       72.0           81.0
# 2017-11-20      82.869715       69.0           83.0
# 2017-11-24      75.786972       67.0           75.0
# 2017-11-25      79.578697       85.0           80.0
# 2017-11-26      87.157870       78.0           88.0
# 2017-12-06      83.415787       88.0           83.0
# 2017-12-09      60.541579       62.0           58.0
# 2017-12-17      67.254158       72.0           68.0
# 2017-12-22      67.025416       65.0           67.0
# 2017-12-28      73.302542       47.0           74.0
# 2017-12-30      76.630254       74.0           77.0
# 2018-01-03      72.463025       75.0           72.0
# 2018-01-06      73.846303       79.0           74.0
# 2018-01-10      72.184630       70.0           72.0
# 2018-01-13      73.818463       82.0           74.0
# 2018-01-17      59.581846       69.0           58.0
# 2018-01-20      74.358185       66.0           76.0
# 2018-01-24      64.135818       80.0           63.0
# 2018-01-31      78.413582       66.0           80.0
# 2018-02-03      69.941358       74.0           69.0
# 2018-02-07      82.594136       77.0           84.0
# 2018-02-10      70.359414       65.0           69.0
# 2018-02-17      69.135941       80.0           69.0
# 2018-02-22      68.113594       54.0           68.0
# 2018-02-24      75.211359       67.0           76.0
# 2018-02-28      74.121136       72.0           74.0
# 2018-03-03      75.812114       56.0           76.0
#
# [127 rows x 14 columns]

# %%
test_list = []
for i in team_joined_df.columns:
    if 'pts' in i:
        test_list.append(i)

# %% [markdown]
# ### Team LinReg

# %%
team_linreg = LinearRegression()
team_linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
score_lr = cross_val_score(team_linreg, X_train, y_train, cv=5)
score_lr
# Out:
# array([0.2323768 , 0.22094993, 0.21195707, 0.20990442, 0.20817141])

# %% [markdown]
# ## Engineer Defender Features

# %%
school_list = school_df['School']

# %%
game_dates = df['date_game'].unique()

# %%
# TEST!!!
game_dates = '2010-11-08'

# %%
for m in game_dates:
    for n in school_list:    
        date_mask = m
        school_mask = n

        df_myteam = df[(df['date_game']==date_mask) & (df['school_id']==school_mask)]
        df_myteam = df_myteam.sort_values(['gs', 'mp'], ascending=False)

        opp_school = list(df_myteam['opp_id'])[0]

        df_opp = df[(df['date_game']==date_mask) & (df['school_id']==opp_school)]
        df_opp = df_opp.sort_values(['gs', 'mp'], ascending=False)

        largest = min([len(df_opp), len(df_myteam)])

        df_myteam = df_myteam[0:largest]
        df_opp = df_opp[0:largest]

        my_team_index = df_myteam.index
        matchup_index = []

        opp_pos_list = df_opp['pos']

        for i in df_myteam['pos']:
            if i == 'PG':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PG':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SG':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'G':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break

            if i == 'SG':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SG':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PG':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'G':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break  

            if i == 'SF':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'F':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break

            if i == 'PF':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'C':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'F':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break

            if i == 'C':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'C':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break

            if i == 'G':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PG':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SG':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'G':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break

            if i == 'F':
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'PF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'SF':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
                for j in df_opp['pos'].index:
                    if df_opp['pos'][j] == 'F':
                        matchup_index.append(j)
                        df_opp['pos'].drop(j, inplace=True)
                        break
            try:
                matchup_index.append(df_opp['pos'].index[0])
                df_opp['pos'].drop(df_opp['pos'].index[0], inplace=True)
            except:
                pass
        df.merge()
        # Do a thing that appends select cols to the right

# %% [markdown]
# # Modeling

# %%
# Specific to rolling mean and rolling median
#all_rolling.append('pts')

# %%
ewm_cols.append('pts')

# %%
test_df = joined_df.dropna()[ewm_cols].drop(['date_game', 'player'], axis=1)

# %%
test_df.head()

# %%
# Come back to set X to drop just pts and 'Unnamed:0'

#X = test_df.drop(['pts'], axis=1)
X = test_df.drop('pts', axis=1)
y = test_df['pts']

# %%
X.columns

# %%
#from sklearn.preprocessing import StandardScaler

# %%
#ss = StandardScaler()
#ss.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %%
linreg = LinearRegression(normalize=True)
linreg.fit(X_train, y_train)

# %%
cross_val_score(linreg, X_train, y_train)

# %%
preds = linreg.predict(X)

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.scatter(preds, y_test)

# %%
linreg.score(X_test, y_test)

# %%
y_test.max()

# %%
preds.max()

# %%
joined_df.head()

# %%
orig_df = joined_df.dropna()

# %%
orig_df['preds'] = preds

# %%
temp = orig_df[['school_id', 'date_game', 'pts', 'preds']].groupby(['school_id', 'date_game']).sum()

# %%
fig, ax = plt.subplots(figsize=(14,6))
plt.scatter(temp['pts'], temp['preds'])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
r2_score(y, preds)

# %%
temp['pts'].mean()

# %%
temp['mean'] = temp['pts'].mean()

# %%
len(temp['pts'])

# %%
mean_score = np.full(86849, temp['pts'].mean())

# %%
real_scores = temp['pts'].values

# %%
r2_score(real_scores, mean_score)

# %%
mean_squared_error(real_scores, mean_score)

# %%
mean_squared_error(real_scores, temp['preds'])

# %%
r2_score(real_scores, temp['preds'])

# %%
plt.hist(real_scores, bins=50)

# %%
np.std(real_scores)

# %%
print(len(temp['pts'].values))
print(len(mean_score))

# %%
mean_sc

# %%
joined_df.head()

# %%
test_df.groupby(['school_id', 'date_game']).sum()

# %% [markdown]
# # Exploratory

# %%
test = joined_df.loc['Grayson Allen'][['mp','pts', 'ewmpts_05', 'ewmgame_score_05', 'date_game']].sort_values('date_game')
test

# %%
fig, ax = plt.subplots(figsize=(14,6))
plt.plot(test['pts'])
#plt.plot(test['mp'])
plt.plot(test['ewmgame_score_05'])

# %%
ewm_test = player_df.drop('date_game', axis=1).ewm(alpha = 0.5).mean().head()
ewm_test

# %%
ewm_test.shift()

# %%
player_df.head()

# %%
test = df.groupby(['school_id', 'season']).sum().sort_values('pts', ascending=False)
test

# %%
test.corr()
